# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\Users\\DonalHarrison\\OneDrive - Aspen Health Inc\\Documents\\local_staging\\flight-delay-risk\\notebooks'

# %%
df = pd.read_parquet("../data/interim/bts_on_time_parquet/YEAR=2023/MONTH=12/20baceea5662451181bbafd6d2810f75-0.parquet")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570394 entries, 0 to 570393
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DAY_OF_MONTH       570394 non-null  Int8
#  1   DAY_OF_WEEK        570394 non-null  Int8
#  2   OP_UNIQUE_CARRIER  570394 non-null  object
#  3   ORIGIN             570394 non-null  string
#  4   DEST               570394 non-null  string
#  5   CRS_DEP_TIME       570394 non-null  Int32
#  6   CRS_ARR_TIME       570394 non-null  Int32
#  7   ARR_DELAY          566941 non-null  float32
#  8   DISTANCE           570394 non-null  float32
#  9   FL_DATE            570394 non-null  datetime64[ns]
#  10  OP_CARRIER_FL_NUM  0 non-null       string
#  11  CANCELLED          570394 non-null  Int8
#  12  DIVERTED           570394 non-null  Int8
#  13  SOURCE_FILE        570394 non-null  object
#  14  CRS_DEP_MINUTES    570394 non-null  float32
# ...

# %%
df.columns
# Out:
# Index(['DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'CRS_ARR_TIME', 'ARR_DELAY', 'DISTANCE', 'FL_DATE',
#        'OP_CARRIER_FL_NUM', 'CANCELLED', 'DIVERTED', 'SOURCE_FILE',
#        'CRS_DEP_MINUTES', 'CRS_ARR_MINUTES', 'CRS_DEP_HOUR', 'CRS_ARR_HOUR'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_parquet("../data/features/base/train/YEAR=2023/MONTH=12/c7fe6511919e479dad91cd85e9670305-0.parquet")
print(sorted(df.columns))
# Out:
# ['CRS_ARR_HOUR', 'CRS_ARR_MINUTES', 'CRS_DEP_HOUR', 'CRS_DEP_MINUTES', 'DAY_OF_WEEK', 'DEST', 'DISTANCE', 'OP_CARRIER', 'ORIGIN', 'day_of_month', 'delayed_15', 'dep_daypart', 'flight_date', 'is_weekend', 'route', 'week_of_year']
